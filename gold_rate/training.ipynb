# %%
from bs4 import BeautifulSoup
import requests
url = "https://www.livechennai.com/gold_silverrate.asp"
resp=requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
l=resp.text.split('\n')

# %%
type(l)
# Out:
# list

# %%
for x,y in enumerate(l):
    print(x,y)
# Out:
# 0
# 1   <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">
# 2   <html>
# 3   <head>
# 4   <meta name="ROBOTS" content="follow,index,all">
# 5   <meta name="viewport" content="width=device-width, initial-scale=1">
# 6   <meta http-equiv="Content-Language" content="en">
# 7   <meta name="Description" content="Gold Rate in Chennai, Gold Rate Today in Chennai, Get Gold Rate/Price in Chennai, Current gold price/rate in Chennai, Chennai Gold market,">
# 8   <meta name="Keywords" content="Gold Rate in Chennai | Gold Rate Today in Chennai | Gold Price Chennai | Current gold price|  Silver Rate Chennai |silver price |gold price in india">
# 9   <meta name="Publisher" content="J B Soft System(www.jbsoftsystem.com)">
# 10   <meta name="revisit-after" content="7 days">
# 11   <meta name="googlebot" content="aLL">
# 12   <meta name="title" content="www.Livechennai.com - Gold Rate in Chennai, Gold Rate Today in Chennai, Gold Rate, Gold Price in Chennai">
# 13   <meta content="J.Sampath" name="author">
# 14   <meta http-equiv="Content-Type" content="text/html; charset=windows-1252">
# 15   <meta http-equiv="refresh">
# 16   <title>Gold Rate in Chennai, Live Chennai Gold/Silver Rate: Gold, Gold Rate, Silver, Silver Rate, India Gold Rate, Gold Rate in India, India Silver Rate, Silver Rate in India,silver price, gold price in india , Silver rate, 24Carat Gold Rate, </title>
# 17   <link rel="stylesheet" type="text/css" href="responsive-css/responsive.css">
# 18   <link rel="stylesheet" type="text/css" href="responsive-css/bootstrap.min.css">
# 19   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# 20   <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 21 <script>
# 22      (adsbygoogle = window.adsbygoogle || []).push({
# 23           google_ad_client: "ca-pub-5210135464026679",
# 24           enable_page_level_ads: true
# 25      });
# 26 </script>
# 27
# 28   <style>
# 29 .table-price{width:98%;border:solid 1px #383737; line-height: 25px;font-size: 13px;}
# 30 #mob-cont{width:96%;border:solid 1px #383737; line-height: 25px; text-align: center;margin-bottom: 30px;}
# 31 table{border:none;}
# 32 .left-list{float:left;}
# 33 .mobile-cat{display:none;}
# 34 .mob-cont tr td span a{font-size: 13px;color: #000000;text-decoration: none;font-weight: bold;line-height: 37px;margin-left: 10px;}
# 35 .mob-details{width: 384px;text-align: justify;height: auto;-webkit-border-radius: 5px;border: solid 1px #ccc;
# 36 box-shadow: 0 1px 4px rgba(0,0,0,.2);margin-top: 125px;margin-bottom: 22px;margin-left: 20px;}
# 37 .mob-details h2 {background: #cc0000;font-family: Verdana;font-size: 14px;margin: 1px;padding: 5px;border-radius: 3px;
# 38 color: #fff;font-weight: bold;}
# 39 .mob-details ul{margin: 0px;padding: 0px;margin-left: 0px;}
# 40 .title-clr{ font-family: Verdana; font-size: 12px; font-weight: 700;color: #444141; }
# 41 .mob-details ul li{list-style: none;line-height: 35px;height: 35px;background: url(images/product-list-bg.gif) repeat-x bottom;}
# 42 .mob-details ul li a {font: 12px Verdana;background: url(images/2.png) left center no-repeat;
# 43 padding: 0px 0px 0px 20px;font-weight: bold;text-decoration: none;margin-left: 15px;color: #000;}
# 44 .mobile-view{display: none;}
# 45 .mob-view{display: none;}
# 46 .mobile-cat1{display: none;}
# 47 .right-side { min-height: 2200px; width: 200px; text-align: center;  /*background-image: url(images/right_bg.jpg);*/
# 48     background-repeat: repeat-y; overflow: hidden;}
# 49 .col-sm-8{margin-left: 112px;  margin-top: -11px;}
# 50 .txt-clr{color: #383737;font-size: 13px;}
# 51 .col-sm-8 h1{ margin-top:-38px;font-size: 13px;font-family:Arial, Helvetica, sans-serif;text-transform: uppercase;font-weight: bold;}
# 52 .left-other-city{float:left;margin-left:10px;background-repeat:no-repeat;margin:0px;border: none; }
# 53 .left-other-city tr td{padding-left: 10px;}
# 54 .left-silver-city{float:left;background-repeat:no-repeat;margin:0px;border: none; margin-top: -16px;}
# 55 .left-silver-city{padding-left: 3px;}
# 56 .left-silver-city tr td a{font-family: Verdana; letter-spacing: normal; color: #00001F; font-size: 13px; font-weight: 700}
# 57 .left-other-city span{font-family: Verdana; letter-spacing: normal; color: #000000; font-size: 13px;font-weight:bold;}
# 58 #other-silver-city{ background-repeat: no-repeat;border: 1px solid #EEE;padding: 15px;border-radius: 16px;background-color: #e2e2e236;}
# 59 #left-gold{width: 206px; margin-left: -9px; border: 1px solid rgba(33, 150, 243, 0.38); border-radius: 17px;}
# 60 #gold-tit{margin-top: 47px;font-size: 13px;font-family:Arial, Helvetica, sans-serif;text-transform: uppercase;font-weight: bold;}
# 61
# 62
# 63 @media only screen and ( max-width: 800px){
# 64 .left-list {display:none;}
# 65 .right-side, .news-leads {display: none;}
# 66 .table-price{width:100%;margin:0px auto;line-height: 25px;border: 1px solid #9c9898;}
# 67 .title-clr{color: #444141;}
# 68 .txt-clr{color: #383737;}
# 69 .col-sm-8{padding-right: 5px; padding-left: 5px;margin-left: 0px;}
# 70 .add{float: left;margin-left: 0px; margin-top: 0px;}
# 71 .mob-details{ display:none;}
# 72 .mob-cont, #mob-cont, .col-sm-12{ display:none;}
# 73 .mobile-cat{display:block; margin-top: -70px;}
# 74 .mobile-cat1{}
# 75 .mobile-view{display: inline;text-align: center;width: 100%;}
# 76 .mobile-view ul{margin-right: 16px; margin-left: -27px; margin-top: 170px;}
# 77 .mobile-view ul li{ background: linear-gradient(to right, rgba(230,168,43,1) 0%, rgba(255,255,255,1) 53%, rgba(230,168,43,1) 100%);
# 78  list-style-type: none;  margin-bottom: 1px;}
# 79 .mobile-view ul li a{ font-weight: bold; line-height: 25px; color: #000; font-size: 14px; text-align: center;}
# 80 .mob-view{display: inline;text-align: center;width: 100%;}
# 81 .mob-view ul{margin-right: 16px; margin-left: -27px;}
# 82 .mob-view ul li{ background: linear-gradient(to right, rgba(232,232,232,1) 0%, rgba(255,255,255,1) 44%, rgba(255,255,255,1) 66%, rgba(232,232,232,1) 100%); list-style-type: none;  margin-bottom: 1px;}
# 83 .mob-view ul li a{font-weight: bold; line-height: 25px; color: #000;font-size: 14px; text-align: center;}
# 84 .col-sm-8 h1{ margin-top: 10px;}
# 85 .mob-viw{margin-bottom: -166px;}
# 86 }
# 87 </style>
# 88 </head>
# 89 <body>
# 90 <!-- Top & Menu Start -->
# 91 <!--  <div class="Top_Ban" ><a href="Mahatria_Birthday_Celebration.asp" target="_blank"><img src="images/Top_banner_2505.jpg"></a></div> -->
# 92 <div class="header">
# 93   <div id="logo"><a href="https://www.livechennai.com/index.asp"><img src="responsive-include/title.png"></a></div>
# 94   <div id="top-add">
# 95 <div style="text-align: right;margin-right: 70px; margin-top: 7px;">
# 96  <!--<a href="https://www.livechennai.com/jbagrofoods.asp" target="_blank"><img src="images/Marchekku_ad.jpg" style="border: 1px solid #FFF;"></a>-->
# 97  </div>
# 98     <!--<A href="http://www.jbcrm.com/" target=_blank><img src="images/JBSOFT_07_06_19.jpg"></A>-->
# 99   </div>
# 100   <div class="clear"></div>
# 101   <link rel="stylesheet" type="text/css" href="responsive-include/res-menu.css">
# 102 <div class="menu" >
# 103   <nav  class="nav-main" >
# 104       <label for="show-menu" class="show-menu">&nbsp;&nbsp;<b onclick="openNav()">&#9776;</b></label>
# 105       <input type="checkbox" id="show-menu" role="button">
# 106
# 107    <div class="link" id="menu">
# 108       <div class="closebtn"><a href="javascript:void(0)"  onclick="closeNav()"><b class="close">&times;</b></a></div>
# 109       <a href="index.asp"><img src="images/res-menu-home.png" class="res-img">Home</a>
# 110       <a href="news_viewall.asp" ><img src="images/res-menu-news.png" class="res-img">News</a>
# 111       <a  href="good_news_chennai1.asp" id="res-hide">Good News</a>
# 112       <a href="chennai-events.asp"> <img src="images/res-menu-event.png" class="res-img">Events</a>
# 113       <a href="gold_silverrate.asp"> <img src="images/res-menu-gold.png" class="res-img">Market Watch</a>
# 114        <a  href="https://classifieds.livechennai.com/" target="_blank" id="res-hide">
# 115       <img src="images/res-menu-classified.png" class="res-img">Classifieds</a>
# 116       <a href="pricelist_chennai.asp"> <img src="images/res-menu-price.png" class="res-img">Price List</a>
# 117       <!--  <a  href="http://metrotrain.livechennai.com/" target="_blank" id="res-hide">Metro Train</a> -->
# 118       <a  href="http://directory.livechennai.com/" target="_blank" id="res-hide">Directory</a>
# 119      <!--  <a  href="http://property.livechennai.com/" target="_blank" id="res-hide">Properties</a> -->
# 120     <!-- <a  href="http://jobs.livechennai.com/" target="_blank" id="res-hide"><img src="images/res-menu-job.png" class="res-img">Jobs</a> -->
# 121    <!--  <a  href="https://www.livechennai.com/detailnews.asp?newsid=43639" target="_blank" id="res-hide">Blood </a> -->
# 122        <!-- <a  href="Chennaihelplines.asp" target="_blank" id="res-hide">Help Lines</a> -->
# 123       <a  href="https://www.livechennai.com/weather.asp"  id="res-hide">Weather</a>
# 124       <!-- <a  href="health_news_in_chennai.asp"  id="res-hide">Health</a> -->
# 125
# 126     <!--  <a href="detailnews.asp?newsid=46739" target="_blank" id="res-hide">Join Rotary</a> -->
# 127       <!-- <a  href="Entertainment_news.asp" target="_blank" id="res-hide">Entertainment</a>-->
# 128      <!--  <a href="http://videos.livechennai.com/" target="_blank" id="res-hide">Videos</a> -->
# 129       <a  href="business_tips.asp" ><img src="images/res-menu-business.png" class="res-img">Business Tips
# 130       <!-- <img src="images/new_animated.gif" class="new-gif"> --></a>
# 131
# 132       <a href="https://tamil.livechennai.com/" target="_blank" id="res-hide"><img src="../images/Tamil-menu.jpg"></a>
# 133       <a  href="detailnews.asp?catid=26&newsid=43639" target="_blank" id="res-hide">Blood</a>
# 134       <a href="services.asp" target="_blank" id="res-hide">Services <img src="images/new_animated.gif"></a>
# 135       <a  href="https://shop.jbagrofoods.in" target="_blank" id="res-hide">Agro Foods<img src="images/new_animated.gif"></a>
# 136       <a  href="products.asp" target="_blank"><img src="images/res-menu-qa.png" class="res-img">Products</a>
# 137
# 138       <!-- <a  href="ro-water-enquiry.asp"><img src="images/res-menu-qa.png" class="res-img">Buy RO<img src="images/new_animated.gif"></a>  -->
# 139       <!-- <a  href="Sell_your_gold.asp"><img src="images/res-menu-qa.png" class="res-img">Sell Gold<img src="images/new_animated.gif"></a> -->
# 140       <!-- <a  href="Business_Networking_Chennai.asp"><img src="images/res-menu-qa.png" class="res-img">CBN</a> -->
# 141       <!-- <a  href="http://www.jobs4all.in/" target="_blank"  id="res-hide">Jobs4all<img src="images/new_animated.gif"></a> -->
# 142       <!-- <a  href="press_release_chennai.asp"  id="res-hide">Press Releases</a>
# 143       <a  href="Questions_Answers.asp"  ><img src="images/res-menu-qa.png" class="res-img">Q&A's</a>
# 144       <a  href="Education_news_chennai.asp" id="res-hide">Education</a>
# 145       <a  href="Education_news_chennai.asp" target="_blank" id="res-hide">Education</a>
# 146       <a href="jbagrofoods.asp" target="_blank" id="res-hide">Shops <img src="images/new_animated.gif"></a>
# 147       <a  href="https://www.livechennai.com/enquiry_form.asp"><img src="images/res-menu-qa.png" class="res-img">Advertise</a>
# 148       <a href="jbagrofoods.asp" target="_blank" id="res-hide">Shops <img src="images/new_animated.gif"></a>
# 149        <a href="Relationship.asp" target="_blank" id="res-hide">Relationship
# 150        <img src="images/new_animated.gif"></a>-->
# 151       <a  href="ChennaiInfo.asp"  id="res-img"><img src="images/res-menu-info.png" class="res-img">Chennai Info</a>
# 152       <a  href="infinitheism.asp"  id="res-img"><img src="images/res-menu-inifini.png" class="res-img">infinitheism</a>
# 153       <a  href="press_release_chennai.asp"  id="res-img"><img src="images/res-menu-news.png" class="res-img">Press Releases</a>
# 154       <a  href="detailnews.asp?newsid=38582"  id="res-img"><img src="images/blood-donation.png" class="res-img">Blood</a>
# 155       <!--<li><A href="https://livechennai.com/vijee_krishnan_recipes.asp" target=_blank>Recipes</A></li>-->
# 156       <!-- <li><a href="http://tamilcinemas.in/" target="_blank">Tamil Cinemas</a></li> -->
# 157       <!-- <li><a href="http://videos.livechennai.com/" target="_blank">Videos</a></li> -->
# 158       <!-- <li><a href="advertise.asp" target="_blank">Advertise</a></li> -->
# 159       <!--<li><a href="http://tamil.livechennai.com/" target="_blank">Tamil</a></li>-->
# 160       <!-- <li><a href="http://tamilnadumlas.com" target="_blank">Tamilnadu MLAs</a></li> -->
# 161       <!--<li><a href="https://www.livechennai.com/cyclone/" target="_blank">
# 162       Cyclone<img src="images/new_animated.gif"></a></li>-->
# 163       <!--<li><a href="https://www.livechennai.com/Astrology.asp" target="_blank">Astrology</a></li>-->
# 164       <!--<li><a href="http://www.jbcrm.com/" target="_blank">Software<img src="images/new_animated.gif"></a></li>-->
# 165       <!--<li><a href="detailnews.asp?newsid=20532" target="_blank">Mobile App</a></li>-->
# 166       <script>
# 167 function openNav() {
# 168     document.getElementById("menu").style.width = "359px";
# 169 }
# 170
# 171 function closeNav() {
# 172     document.getElementById("menu").style.width = "0";
# 173 }
# 174 </script>
# 175     </div>
# 176   </nav>
# 177 </div>
# 178
# 179
# 180   <div class="brk-news">    <!doctype html>
# 181     <html>
# 182     <head>
# 183     <link href='https://fonts.googleapis.com/css?family=Raleway' rel='stylesheet' type='text/css'>
# 184     <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.12.4/jquery.min.js"></script>
# 185     <script src="../scroller-new/jquery.simpleTicker.js"></script>
# 186     <script>
# 187     $(function(){
# 188     $.simpleTicker($("#ticker-fade"),{'effectType':'fade'});
# 189     $.simpleTicker($("#ticker-roll"),{'effectType':'roll'});
# 190     $.simpleTicker($("#ticker-slide"),{'effectType':'slide'});
# 191     $.simpleTicker($("#ticker-one-item"),{'effectType':'fade'});
# 192     });
# 193     </script>
# 194     <style>
# 195
# 196     .tickers{
# 197     margin: 10px auto;
# 198     border: 1px solid rgb(228, 225, 225);
# 199     width: 80%;
# 200     background-color: rgb(250, 250, 250);
# 201     margin-top: -31px;
# 202     margin-right: 50px;
# 203     padding: 3px;
# 204     position: relative;
# 205     overflow: hidden;
# 206     color: #151111;
# 207
# 208     }
# 209     .tickers ul{
# 210     margin:auto;
# 211     position: relative;
# 212     width: 100%;
# 213     }
# 214     .tickers ul li {
# 215     width: 100%;
# 216     display: none;
# 217     font-family: arial;
# 218     }
# 219     .tickers ul li a{ color: #000;}
# 220     div#ticker-roll {  height: 30px !important;}
# 221     .Breaking-News{
# 222     margin: 0 auto;
# 223     width: 15%;
# 224     border: 1px solid;
# 225     padding: 3px;
# 226     margin-left: 11px;
# 227     background-color: #BF263C;
# 228     margin-top: 3px;
# 229     color: #fff;
# 230     font-family: Georgia;
# 231     font-size: 17px;
# 232     }
# 233     .tickers ul li a{font-family: Georgia;font-size: 17px;text-decoration: none;}
# 234     </style>
# 235     </head>
# 236     <body>
# 237     <div class="Breaking-News">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;What's New</div>
# 238     <div id="ticker-roll" class="tickers">
# 239
# 240    <ul>
# 241        <!--<li><a href="detailnews.asp?newsid=49652" target="_blank" style="color: #2c2c80;">Power shutdown areas in Chennai Tomorrow (22-08-2019)</a></li>-->
# 242        <li><a href="https://www.livechennai.com/services.asp" target="_blank" style="color: #BF263C;">Services</a></li>
# 243        <li><a href="https://www.livechennai.com/products.asp" target="_blank" style="color: #BF263C;">Products</a></li>
# 244         <li><a href="https://shop.jbagrofoods.in" target="_blank" style="color: #BF263C;">Agro Foods</a></li>
# 245
# 246
# 247        <!--  <li><a href="https://www.livechennai.com/become_homepreneur.asp" target="_blank" style="color: #BF263C;">Sell Unrefined Sugar (Nattu Sakkarai) to your Neighborhood... Become Homepreneur !</a></li>
# 248
# 249         <li><a href="https://www.livechennai.com/nattu_sakkarai.asp" target="_blank" style="color: #BF263C;">Unrefined Sugar (Nattu Sakkarai) @ Chennai</a></li>
# 250        <li><a href="https://www.livechennai.com/jb_agro_oil_products.asp" target="_blank" style="color: #BF263C;">Buy Pure Mara Chekku Oil !</a>
# 251
# 252     <li><a href="enquiry_form.asp" target="_blank" style="color: #2c2c80;">To Know the Best Price : <img src="images/whatsappmobileno.jpg">  </a></li>
# 253 	<li><a href="enquiry_form.asp" target="_blank" style="color: #242492;">	To Get Business Leads, Enquiries :  <img src="images/whatsappmobileno.jpg">   </a></li>
# 254     <li><a href="enquiry_form.asp" target="_blank" style="color: #242492;"> To Advertise : <img src="images/whatsappmobileno.jpg">   </a></li>
# 255     <li><a href="enquiry_form.asp" target="_blank" style="color: #242492;"> To Post your Contents, Events :  <img src="images/whatsappmobileno.jpg">  </a></li>
# 256     <li><a href="enquiry_form.asp" target="_blank" style="color: #242492;"> To Partner with us : <img src="images/whatsappmobileno.jpg">  </a></li>
# 257     <li><a href="enquiry_form.asp" target="_blank" style="color: #242492;"> To Join and work with us : <img src="images/whatsappmobileno.jpg">   </a></li>
# 258 	<li><a href="clean_aqua_dolphin_water_purifier.asp" target="_blank"> BUY RO @ Unbelievable Price</a></li> -->
# 259
# 260    </ul>
# 261     </div>
# 262
# 263
# 264
# 265     </body>
# 266     </html>
# 267 <bR></div>
# 268 </div>
# 269
# 270
# 271 <style type="text/css">
# 272   .brk-news{ background-color: #fff; padding-top: 5px;}
# 273 /*.Top_Ban{text-align: center;margin-top: -1px;}*/
# 274
# 275 	@media only screen and (max-width: 900px), (max-width: 1024px) {
# 276 /*  .Top_Ban{width: 100%; text-align: center;}*/
# 277  #top-add{display: none;}
# 278  .brk-news{display: none;}
# 279  .header { height: 135px;}
# 280
# 281 </style>
# 282
# 283 <!-- Top & Menu End -->
# 284 <div class="wrapper">
# 285 <div class="veg-cointainer">
# 286 <p class="left-list"><div  style="MARGIN-TOP:-18px; text-align:center; width:105%;line-height: 46px; margin-bottom: 14px;" class="left-list" >
# 287 <!-- <a target="_blank" href="enquiry_form.asp"><IMG border="0" src="images/LC_ad_3011.jpg" ></a><Br> -->
# 288 <a target="_blank" href="petrol_price.asp"><IMG border="0" src="images/petrol_price.jpg" ></a>
# 289 <a target="_blank" href="Commodity_Price_Chennai.asp"><IMG border="0" src="images/Commodity_button.jpg" style="padding-left: 4px;"></a>
# 290 <a target="_blank" href="news_viewall.asp"><IMG border="0" src="Images/latest.jpg" style="padding-left:4px;" ></a>
# 291 <!--<a target="_blank" href="hardware_price_Chennai.asp"><IMG  border="0" src="images/Hardware_price.jpg" style="padding-left:2px;" ></a>
# 292  <a target="_blank" href="Sell_your_gold.asp"><IMG border="0" src="images/Sell_gold_3001.jpg" style="padding-left: 4px;"></a>
# 293  <a target="_blank" href="clean_aqua_dolphin_water_purifier.asp"><IMG src="images/RO_water_ad_100119.jpg" style="padding-left: 4px;"></a> -->
# 294 <br>
# 295     <!-- <a target="_blank" href="Commodity_Price_Chennai.asp">
# 296     <IMG  border="0" src="images/Commodity_button.jpg" style="padding-left:2px;padding-top:5px" >
# 297     <a target="_blank" href="hardware_price_Chennai.asp">
# 298     <IMG  border="0" src="images/Hardware_price.jpg" style="padding-left:2px;padding-top:5px" ></a>
# 299     <a target="_blank" href="news_viewall.asp"><IMG border="0" src="Images/latest.jpg" style="padding-left:4px;padding-top:5px" ></a>
# 300     <a target="_blank" href="foreigncurrency.asp"><IMG border=0 src="images/FE_01.jpg"  style="padding-left: 4px;"></a>
# 301     <a target="_blank" href="https://www.livechennai.com/financial_solution_nikhilsinghi.asp">
# 302     <IMG border="0" src="images/financial_solutions20.png" style="padding-left: 4px;"></a><br>
# 303     -->
# 304
# 305     </div></p><br>
# 306   <h1 class="title" style="border:none;">gold/silver rates in Chennai</h1>
# 307
# 308     <br>
# 309
# 310     <div class="leads" align="center"><style>
# 311 .responsive-ad-unit-1 { width: 320px; height: 50px;}
# 312 @media(min-width: 500px){ .responsive-ad-unit-1 { width: 336px; height: 280px;}}
# 313 @media(min-width: 800px){ .responsive-ad-unit-1 { width: 728px; height: 90px;}}
# 314 @media(min-width: 1024px){ .responsive-ad-unit-1 { width: 336px; height: 280px;}}
# 315 </style>
# 316 <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 317 <!-- 336x280 -->
# 318 <ins class="adsbygoogle"
# 319      style="display:block"
# 320      data-ad-client="ca-pub-5210135464026679"
# 321      data-ad-slot="5222998773"
# 322      data-ad-format="auto"
# 323      data-full-width-responsive="true"></ins>
# 324 <script>
# 325      (adsbygoogle = window.adsbygoogle || []).push({});
# 326 </script></div>
# 327    <br>
# 328
# 329
# 330      <table class="table-price" style="border: none;" >
# 331 <tr>
# 332 <td>
# 333   <div class="col-sm-2">
# 334
# 335
# 336         <table class="left-list"   border="0" style="float: left;margin-top:-36px;border: none;margin-bottom: 25px;">
# 337               <tr>
# 338                 <td valign="center" width="244"><b><font color="#ea8c00"> </font></b>&nbsp;<br>
# 339                   <br>
# 340
# 341            <div class="left-list" id="left-gold">
# 342               <table border="0" class="left-other-city"  cellpadding="0" >
# 343                   <tr align="center"><td> <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 344 <!-- 180x90, created 5/3/11 -->
# 345 <ins class="adsbygoogle"
# 346      style="display:block"
# 347      data-ad-client="ca-pub-5210135464026679"
# 348      data-ad-slot="2577772987"
# 349      data-ad-format="link"
# 350      data-full-width-responsive="true"></ins>
# 351 <script>
# 352      (adsbygoogle = window.adsbygoogle || []).push({});
# 353 </script>
# 354 </td></tr>
# 355                   <tr><td><a href="gold_silverrate.asp"> <span>Gold Rate in Chennai</span></a></td> </tr>
# 356                   <tr><td> <a href="gold_silverrate_Coimbatore.asp"> <span>Gold Rate in Coimbatore</span></a></td></tr>
# 357                   <tr><td> <a href="gold_silverrate_Trichy.asp"> <span>Gold Rate in Trichy</span></a></td></tr>
# 358                   <tr><td><a href="http://vellorecity.com/goldrate_vellore.asp" target="_blank"> <span>Gold Rate in Vellore</span></a></td></tr>
# 359                   <tr><td> <a href="gold_silverrate_mumbai.asp"> <span>Gold Rate in Mumbai</span></a></td></tr><tr>
# 360                   <td><a href="gold_silverrate_delhi.asp"> <span>Gold Rate in Delhi</span></a></td></tr>
# 361                   <tr><td> <a href="gold_silverrate_kolkata.asp"> <span>Gold Rate in Kolkata</span></a></td></tr>
# 362                   <tr><td> <a href="gold_silverrate_Hyderabad.asp"> <span>Gold Rate in Hyderabad</span></a></td></tr>
# 363                   <tr><td> <a href="gold_silverrate_Ahmedabad.asp"> <span>Gold Rate in  Ahmedabad</span></a></td></tr>
# 364                   <tr><td> <a href="gold_silverrate_Trivandrum.asp"> <span>Gold Rate in Trivandrum</span></a></td></tr>
# 365                   <tr><td> <a href="gold_silverrate_Bangalore.asp"> <span>Gold Rate in Bangalore</span></a></td></tr>
# 366                   <tr><td> <a href="gold_silverrate_Jaipur.asp"> <span>Gold Rate in Jaipur</span></a></td></tr>
# 367                   <tr><td> <a href="gold_silverrate_Pune.asp"> <span>Gold Rate in Pune</span></a></td></tr>
# 368                   <tr><td> <a href="gold_silverrate_kochi.asp"> <span>Gold Rate in Kochi</span></a></td></tr>
# 369                   <tr><td> <a href="platinum_rate_chennai.asp"> <span>Platinum Rate Today</span></a></td></tr>
# 370                 </table>
# 371               </div></td></tr></table>
# 372
# 373               </div>
# 374
# 375         <div class="col-sm-8">
# 376         <div style="font-size: 15px;text-align: justify;"><b>Gold rate in Chennai :</b> Live Chennai present to you today gold rate in Chennai. Here, we provide you the exact today prices of 916 kdm hallmark gold in 22 Carat as well as 24 carat gold rate Chennai. These rates are legitimate and up-to-the-minute. We have the rates displayed in different forms including Rate per gram, Rate per 8 grams. Also, the difference in 916 kdm gold rate Chennai as compared to the previous day is clearly put up. Check today Gold rate in Chennai.<br>
# 377         <b style="color: #9c120f;">Today Gold Rate Per Gram in Chennai (INR)</b></div>
# 378
# 379   <p class="left-list" style="border: none;" > <style type="text/css">
# 380
# 381 .dif-width{
# 382 	width: 100%;
# 383 	float: left;
# 384 }
# 385 .dif-width * {
# 386     max-width: 100% !important;
# 387 }
# 388 .dif-width iframe { width: 100% !important; }
# 389 @media only screen and ( max-width: 640px) {
# 390 .dif-width{
# 391 	width: 100%;
# 392 }
# 393 }
# 394 </style>
# 395 <div class="dif-width">
# 396 <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 397 <!â LinkAdsResp16Jun2017 â>
# 398 <ins class="adsbygoogle"
# 399      style="display:block;"
# 400      data-ad-client="ca-pub-5210135464026679"
# 401      data-ad-slot="4875820772"
# 402      data-ad-format="link"></ins>
# 403 <script>
# 404 (adsbygoogle = window.adsbygoogle || []).push({});
# 405 </script>
# 406 </div>
# 407  </p>
# 408
# 409   <div id="gold-tit"  valign="middle">
# 410     <h1>
# 411     <font color="#ea8c00" style="float: left;">
# 412     <img border="0" src="images/goldcoin.jpg" width="47" height="51">&nbsp; Chennai Gold Rate</font></h1>
# 413   </div>
# 414     <p class="mob-cont " align="right" style="font-family:arial;font-size:11px;text-align: right; margin-top: 50px;">LAST UPDATE TIME:03:10:45
# 415    </p>
# 416
# 417
# 418
# 419 <table  border="1" cellpadding="4" class="table-price" bordercolor="#c0c0c0" style=" border-width:1px; BORDER-COLLaPSE: collapse;margin-top: 0px;"  bgcolor="#000080">
# 420           <tr>
# 421             <td rowspan="2" align="center" style="BaCKGROUND-COLOR: #ffffff" bordercolor="#006BBE"><span class="title-clr">Date</span></td>
# 422           <td colspan="2"   style="BaCKGROUND-COLOR: #ffffff;text-align: center;" bordercolor="#006BBE"><span class="title-clr">Pure Gold (24 k)</span></td>
# 423           <td colspan="2"  align="center"  style="BaCKGROUND-COLOR: #ffffff" bordercolor="#006BBE"><span class="title-clr">Standard Gold (22 K)</span></td>
# 424           </tr>
# 425           <tr>
# 426             <td align="center"  style="BaCKGROUND-COLOR: #ffffff" bordercolor="#006BBE"><span class="title-clr">1 grm</span></td>
# 427             <td align="center"  style="BaCKGROUND-COLOR: #ffffff" bordercolor="#006BBE"><span class="title-clr">8 grm</span></td>
# 428             <td align="center"  style="BaCKGROUND-COLOR: #ffffff" bordercolor="#006BBE"><span class="title-clr">1 grm</span></td>
# 429             <td align="center"  style="BaCKGROUND-COLOR: #ffffff" bordercolor="#006BBE"><span class="title-clr">8 grm</span></td>
# 430           </tr>
# 431            <tr>
# 432             <td height="25" class="content" width="9%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE">
# 433     <font class="txt-clr">
# 434     14/October/2019</font></td>
# 435     <td height="25" class="content" width="16%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 436     <font class="txt-clr">3825.00</font></td>
# 437     <td height="25" class="content" width="12%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 438     <font class="txt-clr">30600.00</font></td>
# 439     <td height="25" class="content" width="22%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 440     <font class="txt-clr">3660.00</font></td>
# 441     <td height="25" class="content" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE" width="11%" nowrap="">
# 442     <font class="txt-clr">29280.00</font></td>
# 443
# 444     </tr>
# 445              <tr>
# 446             <td height="25" class="content" width="9%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE">
# 447     <font class="txt-clr">
# 448     13/October/2019</font></td>
# 449     <td height="25" class="content" width="16%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 450     <font class="txt-clr">3809.00</font></td>
# 451     <td height="25" class="content" width="12%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 452     <font class="txt-clr">30472.00</font></td>
# 453     <td height="25" class="content" width="22%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 454     <font class="txt-clr">3644.00</font></td>
# 455     <td height="25" class="content" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE" width="11%" nowrap="">
# 456     <font class="txt-clr">29152.00</font></td>
# 457
# 458     </tr>
# 459
# 460           <tr>
# 461             <td height="25" class="content" width="9%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE">
# 462     <font class="txt-clr">
# 463     12/October/2019</font></td>
# 464     <td height="25" class="content" width="16%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 465     <font class="txt-clr">3809.00</font></td>
# 466     <td height="25" class="content" width="12%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 467     <font class="txt-clr">30472.00</font></td>
# 468     <td height="25" class="content" width="22%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 469     <font class="txt-clr">3644.00</font></td>
# 470     <td height="25" class="content" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE" width="11%" nowrap="">
# 471     <font class="txt-clr">29152.00</font></td>
# 472
# 473     </tr>
# 474
# 475           <tr>
# 476             <td height="25" class="content" width="9%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE">
# 477     <font class="txt-clr">
# 478     11/October/2019</font></td>
# 479     <td height="25" class="content" width="16%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 480     <font class="txt-clr">3810.00</font></td>
# 481     <td height="25" class="content" width="12%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 482     <font class="txt-clr">30480.00</font></td>
# 483     <td height="25" class="content" width="22%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 484     <font class="txt-clr">3653.00</font></td>
# 485     <td height="25" class="content" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE" width="11%" nowrap="">
# 486     <font class="txt-clr">29224.00</font></td>
# 487
# 488     </tr>
# 489
# 490           <tr>
# 491             <td height="25" class="content" width="9%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE">
# 492     <font class="txt-clr">
# 493     10/October/2019</font></td>
# 494     <td height="25" class="content" width="16%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 495     <font class="txt-clr">3827.00</font></td>
# 496     <td height="25" class="content" width="12%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 497     <font class="txt-clr">30616.00</font></td>
# 498     <td height="25" class="content" width="22%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 499     <font class="txt-clr">3670.00</font></td>
# 500     <td height="25" class="content" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE" width="11%" nowrap="">
# 501     <font class="txt-clr">29360.00</font></td>
# 502
# 503     </tr>
# 504
# 505           <tr>
# 506             <td height="25" class="content" width="9%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE">
# 507     <font class="txt-clr">
# 508     09/October/2019</font></td>
# 509     <td height="25" class="content" width="16%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 510     <font class="txt-clr">3815.00</font></td>
# 511     <td height="25" class="content" width="12%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 512     <font class="txt-clr">30520.00</font></td>
# 513     <td height="25" class="content" width="22%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 514     <font class="txt-clr">3658.00</font></td>
# 515     <td height="25" class="content" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE" width="11%" nowrap="">
# 516     <font class="txt-clr">29264.00</font></td>
# 517
# 518     </tr>
# 519
# 520           <tr>
# 521             <td height="25" class="content" width="9%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE">
# 522     <font class="txt-clr">
# 523     08/October/2019</font></td>
# 524     <td height="25" class="content" width="16%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 525     <font class="txt-clr">3805.00</font></td>
# 526     <td height="25" class="content" width="12%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 527     <font class="txt-clr">30440.00</font></td>
# 528     <td height="25" class="content" width="22%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 529     <font class="txt-clr">3648.00</font></td>
# 530     <td height="25" class="content" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE" width="11%" nowrap="">
# 531     <font class="txt-clr">29184.00</font></td>
# 532
# 533     </tr>
# 534
# 535           <tr>
# 536             <td height="25" class="content" width="9%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE">
# 537     <font class="txt-clr">
# 538     07/October/2019</font></td>
# 539     <td height="25" class="content" width="16%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 540     <font class="txt-clr">3809.00</font></td>
# 541     <td height="25" class="content" width="12%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 542     <font class="txt-clr">30472.00</font></td>
# 543     <td height="25" class="content" width="22%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 544     <font class="txt-clr">3652.00</font></td>
# 545     <td height="25" class="content" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE" width="11%" nowrap="">
# 546     <font class="txt-clr">29216.00</font></td>
# 547
# 548     </tr>
# 549
# 550           <tr>
# 551             <td height="25" class="content" width="9%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE">
# 552     <font class="txt-clr">
# 553     06/October/2019</font></td>
# 554     <td height="25" class="content" width="16%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 555     <font class="txt-clr">3805.00</font></td>
# 556     <td height="25" class="content" width="12%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 557     <font class="txt-clr">30440.00</font></td>
# 558     <td height="25" class="content" width="22%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 559     <font class="txt-clr">3648.00</font></td>
# 560     <td height="25" class="content" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE" width="11%" nowrap="">
# 561     <font class="txt-clr">29184.00</font></td>
# 562
# 563     </tr>
# 564
# 565           <tr>
# 566             <td height="25" class="content" width="9%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE">
# 567     <font class="txt-clr">
# 568     05/October/2019</font></td>
# 569     <td height="25" class="content" width="16%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 570     <font class="txt-clr">3805.00</font></td>
# 571     <td height="25" class="content" width="12%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 572     <font class="txt-clr">30440.00</font></td>
# 573     <td height="25" class="content" width="22%" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF">
# 574     <font class="txt-clr">3648.00</font></td>
# 575     <td height="25" class="content" style="TEXT-aLIGN: center; BaCKGROUND-COLOR: #FFFFFF" bordercolor="#006BBE" width="11%" nowrap="">
# 576     <font class="txt-clr">29184.00</font></td>
# 577
# 578     </tr>
# 579
# 580
# 581         </table>
# 582 <br>
# 583
# 584
# 585      <table border="1" id="mob-cont">
# 586    <tr>
# 587    <td><a href="diamond_rate_in_chennai.asp" target="_blank" style="font-size: 15px;text-decoration: none;color: #C00;"> Diamond Rate in Chennai</a></td>
# 588    <td><a href="goldrate_history_in_chennai.asp" target="_blank" style="font-size: 15px;text-decoration: none;color: #C00;">Gold Rate History in Chennai</a></td>
# 589    </tr>
# 590    <tr>
# 591    <td><a href="18k_goldrate_chennai.asp" target="_blank" style="font-size: 15px;text-decoration: none;color: #C00;"> 18k Gold Rate in Chennai</a></td>
# 592    <td><a href="platinum_rate_chennai.asp" target="_blank" style="font-size: 15px;text-decoration: none;color: #C00;"> Platinum Rate in Chennai</a></td>
# 593    </tr>
# 594    <!-- <tr>
# 595    <td colspan="2"><a href="https://www.livechennai.com/nattu_sakkarai.asp" target="_blank" style="font-size: 15px;text-decoration: none;color: #0c18b5;"> Buy Pure Nattu Sakkarai @ Chennai </a></td>
# 596       </tr> -->
# 597    </table>
# 598    <!-- <div class="mob-cont" style="text-align:right; width:479px;margin-top: -10px;    margin-bottom: -19px;"><span class="index-more19"><a href="Sell_your_gold.asp" target="_blank" style="font-size: 16px;text-decoration: none;color: #C00;font-weight: bold;"> SELL YOUR GOLD</a></span></div>
# 599     <div class="mob-cont" style="text-align:right; width:479px;margin-top: -10px;    margin-bottom: -21px;"><span class="index-more19"><a href="18k_goldrate_chennai.asp" target="_blank" style="font-size: 16px;text-decoration: none;color: #C00;font-weight: bold;"> 18k Gold Rate In Chennai</a></span></div>
# 600 <br>
# 601
# 602    <div style="text-align:left; margin-top: -33px;margin-bottom: 20px;"><span class="index-more19"><a href="goldrate_history_in_chennai.asp" target="_blank" style="font-size: 16px;text-decoration: none;color: #C00;font-weight: bold;">Gold Rate History In Chennai</a></span></div> -->
# 603
# 604    </div>
# 605    </td></tr></table>
# 606 <br>
# 607
# 608       <div class="mob-cont"><style>
# 609 .responsive-ad-unit-1 { width: 320px; height: 50px;}
# 610 @media(min-width: 500px){ .responsive-ad-unit-1 { width: 336px; height: 280px;}}
# 611 @media(min-width: 800px){ .responsive-ad-unit-1 { width: 728px; height: 90px;}}
# 612 @media(min-width: 1024px){ .responsive-ad-unit-1 { width: 336px; height: 280px;}}
# 613 </style>
# 614 <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 615 <!-- 336x280 -->
# 616 <ins class="adsbygoogle"
# 617      style="display:block"
# 618      data-ad-client="ca-pub-5210135464026679"
# 619      data-ad-slot="5222998773"
# 620      data-ad-format="auto"
# 621      data-full-width-responsive="true"></ins>
# 622 <script>
# 623      (adsbygoogle = window.adsbygoogle || []).push({});
# 624 </script></div>
# 625 <br>
# 626
# 627 <table class="table-price" style="border: none;" >
# 628 <tr>
# 629 <td>
# 630     <div class="col-sm-2">
# 631        <div class="left-list" id="other-silver-city">
# 632              <table border="0"   cellpadding="0" class="left-silver-city">
# 633
# 634     <tr><td  nowrap><a href="gold_silverrate.asp"> Silver Rate in Chennai</a> </td></tr>
# 635     <tr><td  nowrap> <a href="silverrate_Coimbatore.asp" >Silver Rate in  Coimbatore</a> </td></tr>
# 636     <tr><td  nowrap><a href="silverrate_Trichy.asp">Silver Rate in Trichy</a> </td> </tr>
# 637     <tr><td  nowrap> <a href="silverrate_delhi.asp">Silver Rate in Delhi </a> </td> </tr>
# 638     <tr><td  nowrap> <a href="silverrate_mumbai.asp" >Silver Rate in Mumbai</a> </td> </tr>
# 639     <tr><td  nowrap><a href="silverrate_kolkata.asp" >Silver Rate in Kolkata</a></td> </tr>
# 640     <tr><td  nowrap><a href="silverrate_Hyderabad.asp" >Silver Rate in Hyderabad</a></td> </tr>
# 641     <tr><td  nowrap> <a href="silverrate_Trivandrum.asp" >Silver Rate in Trivandrum</a> </td> </tr>
# 642     <tr><td  nowrap><a href="silverrate_Bangalore.asp" >Silver Rate in Bangalore</a></td></tr>
# 643     <tr><td  nowrap> <a href="silverrate_Jaipur.asp" >Silver Rate in Jaipur</a></td></tr>
# 644     <tr><td  nowrap><a href="silverrate_Pune.asp" >Silver Rate in Pune</a></td></tr>
# 645     <tr><td  nowrap><a href="silverrate_Ahmedabad.asp" >Silver Rate in Ahmedabad</a></td></tr>
# 646     <tr><td  nowrap><a href="silverrate_kochi.asp" >Silver Rate in Kochi</a></td> </tr>
# 647                     </table>
# 648                   </div>
# 649     </div>
# 650 <br>
# 651       <div align="center" class="mobile-cat"><style type="text/css">
# 652 .CM_LC_GSR_ATF_LB { display:inline-block; width: 300px; height: 250px; }
# 653 @media (max-width:749px) { .CM_LC_GSR_ATF_LB { width: 300px; height: 250px; } }
# 654 @media (min-width:750px) { .CM_LC_GSR_ATF_LB { width: 728px; height: 90px; } }
# 655 </style>
# 656 <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 657 <!-- CM_LC_GSR_ATF_LB -->
# 658 <ins class="adsbygoogle CM_LC_GSR_ATF_LB"
# 659 data-ad-client="ca-pub-5210135464026679"
# 660 data-ad-slot="9929732934"></ins>
# 661 <script>
# 662 (adsbygoogle = window.adsbygoogle || []).push({});
# 663 </script>
# 664
# 665
# 666 </div><br>
# 667
# 668 <div class="col-sm-8" valign="middle">
# 669      <h1 style="s">
# 670       <font color="#999999" style="margin-left: 15px;">
# 671        <img border="0" src="images/silvercoin.jpg" width="47" height="51">&nbsp; Chennai Silver Rate</font>
# 672      </h1>
# 673           <table class="table-price" cellpadding="4" border="1" style="BORDER-BOTTOM-COLOR: #666666; BORDER-TOP-COLOR: #666666; BORDER-COLLAPSE: collapse; BORDER-RIGHT-COLOR: #666666; BORDER-LEFT-COLOR: #666666;border-collapse: collapse; text-align: center; line-height: 27px;margin-bottom: 50px;">
# 674          <tr>
# 675            <td   style="BACKGROUND-COLOR: #e2e2e2;FONT-WEIGHT: 700;font-family: Verdana;" bordercolor="#808080">Date</td>
# 676            <td  style="BACKGROUND-COLOR: #e2e2e2;width: 30%;FONT-WEIGHT: 700;font-family: Verdana;" bordercolor="#808080">Silver 1 Grm</td>
# 677            <td   style="BACKGROUND-COLOR: #e2e2e2;FONT-WEIGHT: 700;font-family: Verdana;" bordercolor="#808080">Ready Silver(1Kg)</td>
# 678          </tr>
# 679           <tr>
# 680         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 681         <font color="#484848">14/October/2019</font></td>
# 682         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 683         <font color="#484848">49.30</font></td>
# 684         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 685         <font color="#484848">49300.00</font></td>
# 686       </tr>
# 687      <tr>
# 688         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 689         <font color="#484848"> 13/October/2019</font></td>
# 690         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 691         <font color="#484848">49.10</font></td>
# 692         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 693         <font color="#484848">49100.00</font></td>
# 694       </tr>
# 695
# 696       <tr>
# 697         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 698         <font color="#484848"> 12/October/2019</font></td>
# 699         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 700         <font color="#484848">49.10</font></td>
# 701         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 702         <font color="#484848">49100.00</font></td>
# 703       </tr>
# 704
# 705       <tr>
# 706         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 707         <font color="#484848"> 11/October/2019</font></td>
# 708         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 709         <font color="#484848">49.50</font></td>
# 710         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 711         <font color="#484848">49500.00</font></td>
# 712       </tr>
# 713
# 714       <tr>
# 715         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 716         <font color="#484848"> 10/October/2019</font></td>
# 717         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 718         <font color="#484848">49.90</font></td>
# 719         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 720         <font color="#484848">49900.00</font></td>
# 721       </tr>
# 722
# 723       <tr>
# 724         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 725         <font color="#484848"> 09/October/2019</font></td>
# 726         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 727         <font color="#484848">49.90</font></td>
# 728         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 729         <font color="#484848">49900.00</font></td>
# 730       </tr>
# 731
# 732       <tr>
# 733         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 734         <font color="#484848"> 08/October/2019</font></td>
# 735         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 736         <font color="#484848">49.00</font></td>
# 737         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 738         <font color="#484848">49000.00</font></td>
# 739       </tr>
# 740
# 741       <tr>
# 742         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 743         <font color="#484848"> 07/October/2019</font></td>
# 744         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 745         <font color="#484848">48.90</font></td>
# 746         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 747         <font color="#484848">48900.00</font></td>
# 748       </tr>
# 749
# 750       <tr>
# 751         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 752         <font color="#484848"> 06/October/2019</font></td>
# 753         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 754         <font color="#484848">49.10</font></td>
# 755         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 756         <font color="#484848">49100.00</font></td>
# 757       </tr>
# 758
# 759       <tr>
# 760         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 761         <font color="#484848"> 05/October/2019</font></td>
# 762         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 763         <font color="#484848">49.10</font></td>
# 764         <td style="TEXT-ALIGN: center; BACKGROUND-COLOR: #ffffff" bordercolor="#808080">
# 765         <font color="#484848">49100.00</font></td>
# 766       </tr>
# 767
# 768
# 769       </table>
# 770       </div>
# 771   <br>
# 772
# 773
# 774 <div class="col-sm-12">
# 775     <!--   <img border="0" src="https://goldprice.org/charts/gold_3d_g_INR.png" class="charts" >  -->
# 776      <div style="font-size: 15px;text-align: justify;">
# 777       <h4 style="color:#e0121e;"> Gold Rate in Chennai</h4>
# 778       There is no denying to the fact that gold is a much sought-after metal in Chennai. The yellow metal gets sold in different forms: gold coins, jewelries, bullion, etc. Often times, the idea of buying gold in Chennai is to signify one's status and wealth and to follow traditional system of investment.<br><br>
# 779
# 780       In India, gold trade and Gold Rate in Chennai has a huge impact on the whole. Gold in Chennai is widely purchased not just for personal celebrations like wedding or birthday parties, but also for events like Akshaya Tritiya when there are a lots of discounts, slashed rates, exciting offers and more to entice the customers.<br><br>
# 781
# 782       Coming on to the elements that determine the Today Gold rate in Chennai, there are many:<br>
# 783
# 784      <b>&bull; </b>State taxes<br>
# 785
# 786       <b>&bull; </b>Local taxes<br>
# 787
# 788       <b>&bull; </b>Transportation taxes<br>
# 789
# 790       <b>&bull; </b>Additional costs incurred by jewelries in Chennai<br>
# 791
# 792      There are a lot of factors that impact gold purchase. This includes monsoon, harvest season, etc.<br><br>
# 793
# 794     <b style="color:#e0121e;">Gold investment in Chennai</b><br><br>
# 795
# 796 There are a lot of people who love to buy gold in Chennai as a form of investment. Gold rate in Chennai has consistently been breaking the inflation for years, say experts. Hence, they suggest, customers should not get too much involved in buying gold in Chennai as short term.
# 797 <br><br>
# 798
# 799 <b style="color:#e0121e;">Buying gold coins in Chennai</b><br><br>
# 800
# 801 There are a lot of private gold sellers in Chennai and banks including SBI that sells gold coins in Chennai. This largely reduces the likeliness of fraudulence in gold purchase in Chennai. These coins are available in different sizes ranging from 2 to 50 grams. As far as buying gold coins is concerned, the purity of gold is assured, but there is no guarantee in buying back the coins though. This is one of the most important reasons for buyers to opt for gold jewelries than coins. Furthermore, buyers will have to pay out extra sum towards premium for buying gold coins from banks.<br><br>
# 802
# 803     </div>
# 804     </div>
# 805
# 806
# 807  <br>
# 808     <br>
# 809
# 810
# 811       <div>
# 812        <table class="mob-cont"  border="0" style="border:solid 1px eee; border-radius:5px; background:#F8F8F8 ; box-shadow: 0 1px 4px rgba(0,0,0,.2); float:left;width: 413px;">
# 813            <tr align="center">
# 814               <td colspan="2" height="41" style="background-color:cc0000; color:#FFFFFF; font-size:17px; border-radius:3px; font-weight: bold;">Compare Today Chennai Gold Jewellers<br> Rate, Schemes &  Offers<!--<img src="images/ynew.gif">-->
# 815                </td>
# 816             </tr>
# 817              <tr>
# 818             <td><img src="images/gold-house18919.jpg" style="border:solid 1px #FF0000; border-radius:3px;margin-left: 5px;"></td>
# 819             <td width="90%" style="border-bottom: 1px solid #cccccc;"><span class="index-more1"><a href="chennai_gold_house.asp">
# 820              Gold Rate in Chennai Gold House & Schemes</a></td>
# 821           </tr>
# 822             <tr>
# 823                <td><img src="images/gggrt.jpg" style="border:solid 1px #FF0000; border-radius:3px;margin-left: 5px;"></td>
# 824                 <td width="90%" style="border-bottom: 1px solid #cccccc;"><span class="index-more1"><a href="grt_jewellery_gold_rate.asp">
# 825                 Gold Rate in GRT Jewellery & Schemes </a></td>
# 826             </tr>
# 827          <tr>
# 828             <td><img src="images/princeicon.jpg" style="border:solid 1px #FF0000; border-radius:3px;margin-left: 5px;"></td>
# 829              <td width="90%" style="border-bottom: 1px solid #cccccc;"><span class="index-more1"><a href="prince_jewellery_gold_rate.asp">Gold Rate in Prince Jewellery & Schemes </a></td>
# 830          </tr>
# 831          <tr>
# 832              <td><img src="images/laithai.jpg" style="border:solid 1px #FF0000; border-radius:3px;margin-left: 5px;"></td>
# 833              <td style="border-bottom: 1px solid #cccccc;"><span class="index-more1"><a href="lalitha_jewellery_gold_rate.asp"> Gold Rate in Lalithaa Jewellery & Schemes </a></td>
# 834          </tr>
# 835          <tr>
# 836             <td><img src="images/sreek-umaran.jpg" style="border:solid 1px #FF0000; border-radius:3px;margin-left: 5px;"></td>
# 837              <td width="90%" style="border-bottom: 1px solid #cccccc;"><span class="index-more1"><a href="/sri_kumaran_jewellery_gold_rate.asp">Gold Rate in Sree Kumaran Thangamaligai & Schemes  </a></td>
# 838           </tr>
# 839          <tr>
# 840             <td><img src="images/naaa.jpg" style="border:solid 1px #FF0000; border-radius:3px;margin-left: 5px;"></td>
# 841              <td width="90%" style="border-bottom: 1px solid #cccccc;"><span class="index-more1"><a href="kalyan_jewellery_chennai.asp">
# 842              Gold Rate in Kalyan Jewellery & Schemes </a></td>
# 843           </tr>
# 844           <tr>
# 845               <td width="10%"><img src="images/ssss.jpg" style="border:solid 1px #FF0000; border-radius:3px;margin-left: 5px;"></td>
# 846               <td width="90%" style="border-bottom: 1px solid #cccccc;"><span class="index-more1"><a href="saravana_jewellery_gold_rate.asp"> Gold Rate in Saravana Stores Thanga Nagai Maligai</a></td>
# 847           </tr>
# 848           <tr>
# 849             <td><img src="images/JOY.jpg" style="border:solid 1px #FF0000; border-radius:3px;margin-left: 5px;"></td>
# 850             <td width="90%" style="border-bottom: 1px solid #cccccc;"><span class="index-more1"><a href="joyalukkas_jewellery_gold_rate.asp">Gold Rate in Joyalukkas Jewellery & Schemes </a></td>
# 851           </tr>
# 852
# 853
# 854          </table>
# 855          <div class="mob-cont" style="float: right; width:40%;">
# 856       <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 857 <!â LinkAdsResp16Jun2017 â>
# 858 <ins class="adsbygoogle"
# 859      style="display:block;"
# 860      data-ad-client="ca-pub-5210135464026679"
# 861      data-ad-slot="4875820772"
# 862      data-ad-format="link"></ins>
# 863 <script>
# 864 (adsbygoogle = window.adsbygoogle || []).push({});
# 865 </script></div>
# 866       <div class="news-leads" align="right"></div>
# 867      </div>
# 868
# 869 <!-- mobile view -->
# 870       <div align="center" class="mobile-view">
# 871        <div>&nbsp;</div>
# 872       <!-- <a href="https://api.whatsapp.com/send?phone=919840279047" target="_blank"><img src="images/Salesboost-livechennai 28.jpg"></a> -->
# 873       <style type="text/css">
# 874
# 875 .dif-width{
# 876 	width: 100%;
# 877 	float: left;
# 878 }
# 879 .dif-width * {
# 880     max-width: 100% !important;
# 881 }
# 882 .dif-width iframe { width: 100% !important; }
# 883 @media only screen and ( max-width: 640px) {
# 884 .dif-width{
# 885 	width: 100%;
# 886 }
# 887 }
# 888 </style>
# 889 <div class="dif-width">
# 890 <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 891 <!â LinkAdsResp16Jun2017 â>
# 892 <ins class="adsbygoogle"
# 893      style="display:block;"
# 894      data-ad-client="ca-pub-5210135464026679"
# 895      data-ad-slot="4875820772"
# 896      data-ad-format="link"></ins>
# 897 <script>
# 898 (adsbygoogle = window.adsbygoogle || []).push({});
# 899 </script>
# 900 </div>
# 901
# 902       </div>
# 903        <div class="mob-viw">&nbsp;</div>
# 904
# 905
# 906       <div class="mobile-view">
# 907              <ul>
# 908                       <li><a href="gold_silverrate_Coimbatore.asp"> Gold Rate in Coimbatore</a></li>
# 909                       <li><a href="gold_silverrate_Trichy.asp">Gold Rate in  Trichy</a></li>
# 910                       <li><a href="gold_silverrate_Chennai.asp">Gold Rate in Chennai</a></li>
# 911                       <li><a href="http://www.vellorecity.com/goldrate_vellore.asp" target=_blank>Vellore Gold Rate</a></li>
# 912                       <li><a href="gold_silverrate_mumbai.asp">Gold Rate in Mumbai</a></li>
# 913                       <li><a href="gold_silverrate_delhi.asp">Gold Rate in Delhi</a></li>
# 914                       <li><a href="gold_silverrate_kolkata.asp">Gold Rate in Kolkata</a></li>
# 915                       <li><a href="gold_silverrate_Hyderabad.asp">Gold Rate in Hyderabad</a></li>
# 916                       <li><a href="gold_silverrate_Ahmedabad.asp">Gold Rate in Ahmedabad</a></li>
# 917                       <li><a href="gold_silverrate_Trivandrum.asp">Gold Rate in Trivandrum</a></li>
# 918                       <li><a href="gold_silverrate_Bangalore.asp">Gold Rate in Bangalore</a></li>
# 919                       <li><a href="gold_silverrate_Jaipur.asp">Gold Rate in Jaipur</a></li>
# 920                       <li><a href="gold_silverrate_Pune.asp">Gold Rate in Pune</a></li>
# 921                       <li><a href="gold_silverrate_kochi.asp">Gold Rate in Kochi</a></li>
# 922                       <li><a class="red" href="platinum_rate_chennai.asp">Platinum Rate Chennai</a></li>
# 923                   </ul>
# 924         </div>
# 925         <br><div class="mobile-cat1"><script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 926 <ins class="adsbygoogle"
# 927      style="display:inline-block;width:336px;height:280px"
# 928      data-ad-client="ca-pub-5210135464026679"
# 929      data-ad-slot="6872303038"></ins>
# 930 <script>
# 931      (adsbygoogle = window.adsbygoogle || []).push({});
# 932 </script></div><br>
# 933         <div class="mob-view">
# 934              <ul>
# 935                        <li><a href="gold_silverrate.asp">Silver Rate in Chennai</a></li>
# 936                       <li><a href="silverrate_Coimbatore.asp">Silver Rate in Coimbatore</a></li>
# 937                       <li><a href="silverrate_Trichy.asp">Silver Rate in Trichy</a></li>
# 938                       <li><a href="silverrate_Chennai.asp">Silver Rate in Chennai</a></li>
# 939                       <li><a href="silverrate_delhi.asp">Silver Rate in Delhi</a></li>
# 940                       <li><a href="silverrate_mumbai.asp">Silver Rate in Mumbai</a></li>
# 941                       <li><a href="silverrate_kolkata.asp">Silver Rate in Kolkata</a></li>
# 942                       <li><a href="silverrate_Hyderabad.asp">Silver Rate in Hyderabad</a></li>
# 943                       <li><a href="silverrate_Trivandrum.asp">Silver Rate in Trivandrum</a></li>
# 944                       <li><a href="silverrate_Bangalore.asp">Silver Rate in Bangalore</a></li>
# 945                       <li><a href="silverrate_Jaipur.asp">Silver Rate in Jaipur</a></li>
# 946                       <li><a href="silverrate_Pune.asp">Silver Rate in Pune</a></li>
# 947                       <li><a href="silverrate_Ahmedabad.asp">Silver Rate in Ahmedabad</a></li>
# 948                       <li><a href="silverrate_kochi.asp">Silver Rate in Kochi</a></li>
# 949                   </ul>
# 950         </div>
# 951
# 952       <!-- mobile nview end -->
# 953
# 954
# 955
# 956   </div>
# 957
# 958     </td></tr>
# 959 </table>
# 960 <div class="mob-details" >
# 961         <h2>International Gold Rate & Silver Rate</h2>
# 962               <ul>
# 963                   <li><a href="goldrate_in_dubai.asp" > Gold Rate in Dubai</a></li>
# 964                    <li><a href="goldrate_in_kuwait.asp" >Gold Rate in Kuwait</a></li>
# 965                </ul>
# 966     </div>
# 967
# 968      <p class="mob-cont" align="justify" style="font-family:arial; font-size:14px; width: 100%;"><b style="color:#cc0000;">Disclaimer:</b>
# 969          Gold rates in Chennai indicated in this page makes no guarantee or warranty on the accuracy or completeness of the data provided on this site. Nothing contained herein is intended or shall be deemed to be investment advice, implied or otherwise. Always consult your registered adviser to assist you with your investments.
# 970      </p>
# 971
# 972      <p style="text-align: right;" align="right"> <A href="#top"> <font color="#000080" face="Verdana" style="FONT-SIZE: 8pt; FONT-WEIGHT: 700"> ^Top </font></a><br> &nbsp;</p>
# 973
# 974   <!-- Google Add End-->
# 975 </div>
# 976 <!-- Right & Section Start -->
# 977  <div class="right-side extraheight" style="height:2200px !important">
# 978
# 979 <p><a href="https://www.livechennai.com/detailnews.asp?newsid=49221&catid=26" target="_blank"> <img border="1" src="ads/Mahatria_2.jpg"> </a></p>
# 980
# 981
# 982
# 983 <p>
# 984   <script async src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 985 <!-- 160x600_LC -->
# 986 <ins class="adsbygoogle"
# 987      style="display:block"
# 988      data-ad-client="ca-pub-5210135464026679"
# 989      data-ad-slot="2268843273"
# 990      data-ad-format="auto"
# 991      data-full-width-responsive="true"></ins>
# 992 <script>
# 993      (adsbygoogle = window.adsbygoogle || []).push({});
# 994 </script>
# 995 </p>
# 996
# 997  <!-- <p><a href="https://www.livechennai.com/nattu_sakkarai.asp" target="_blank"> <img border="1" src="images/nattu-sakkarai0419.jpg" style="border: 1px solid #fe0000;"> </a></p>  -->
# 998 <!-- <p><a href="Sell_your_gold.asp" target="_blank"> <img src="images/Sell_gold_3001_01.jpg" style="border: 1px solid #676363;"  > </a></p> -->
# 999 <!--<p><a target="_blank" href="https://www.facebook.com/livechennai"> <img border="1" src="images/FB_Like_ad.jpg" ></a></p>-->
# 1000
# 1001
# 1002 <p>&nbsp;</p>
# 1003 <p>&nbsp;</p>
# 1004
# 1005  </div>
# 1006 <!-- Right & Section Start -->
# 1007 </div>
# 1008 <div class="clear"></div>
# 1009 <div>
# 1010 <!-- Footer & Section Start -->
# 1011 <div class="fotter"><div align="center">
# 1012 <div class="clearres"></div>
# 1013
# 1014 <style type="text/css">
# 1015
# 1016 .dif-width{
# 1017 	width: 100%;
# 1018 	float: left;
# 1019 }
# 1020 .dif-width * {
# 1021     max-width: 100% !important;
# 1022 }
# 1023 .dif-width iframe { width: 100% !important; }
# 1024 @media only screen and ( max-width: 640px) {
# 1025 .dif-width{
# 1026 	width: 100%;
# 1027 }
# 1028 }
# 1029 </style>
# 1030 <div class="dif-width">
# 1031 <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# 1032 <!â 970x90_30Mar2018 â>
# 1033 <ins class="adsbygoogle"
# 1034      style="display:inline-block;width:970px;height:90px"
# 1035      data-ad-client="ca-pub-5210135464026679"
# 1036      data-ad-slot="1880707206"></ins>
# 1037 <script>
# 1038 (adsbygoogle = window.adsbygoogle || []).push({});
# 1039 </script>
# 1040
# 1041 </div>
# 1042
# 1043
# 1044
# 1045 <!-- Default Statcounter code for livechennai
# 1046 https://livechennai.com/ -->
# 1047 <script type="text/javascript">
# 1048 var sc_project=6829436;
# 1049 var sc_invisible=1;
# 1050 var sc_security="69bf0009";
# 1051 </script>
# 1052 <script type="text/javascript"
# 1053 src="https://www.statcounter.com/counter/counter.js"
# 1054 async></script>
# 1055 <noscript><div class="statcounter"><a title="Web Analytics"
# 1056 href="https://statcounter.com/" target="_blank"><img
# 1057 class="statcounter"
# 1058 src="https://c.statcounter.com/6829436/0/69bf0009/1/"
# 1059 alt="Web Analytics"></a></div></noscript>
# 1060 <!-- End of Statcounter Code -->
# 1061 <script type="text/javascript">
# 1062 var gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "https://www.");
# 1063 document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
# 1064 </script>
# 1065 <script type="text/javascript">
# 1066 try {
# 1067 var pageTracker = _gat._getTracker("UA-1004814-12");
# 1068 pageTracker._trackPageview();
# 1069 } catch(err) {}</script>
# 1070
# 1071
# 1072 <!-- Footer & Section End -->
# 1073 </div>
# 1074 </body>
# 1075 <!-- Main div end -->
# 1076
# 1077 </html>
# 1078
# 1079
# 1080
# 1081
# 1082
