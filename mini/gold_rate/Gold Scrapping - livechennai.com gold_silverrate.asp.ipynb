# %%
#sample code NOT to be executed!!!
data = []
table = soup.find('table', attrs={'class':'lineItemsTable'})
table_body = table.find('tbody')

rows = table_body.find_all('tr')
for row in rows:
    cols = row.find_all('td')
    cols = [ele.text.strip() for ele in cols]
    data.append([ele for ele in cols if ele]) # Get rid of empty values
# Out:
# Error: Jupyter cannot be started. Error attempting to locate jupyter: Data Science libraries jupyter and notebook are not installed in interpreter Python 3.8.2 32-bit.
# at C.startServer (c:\Users\rravi\.vscode\extensions\ms-python.python-2020.4.74986\out\client\extension.js:75:829553)
# at async C.createServer (c:\Users\rravi\.vscode\extensions\ms-python.python-2020.4.74986\out\client\extension.js:75:828996)
# at async C.ensureServerAndNotebookImpl (c:\Users\rravi\.vscode\extensions\ms-python.python-2020.4.74986\out\client\extension.js:1:863926)
# at async C.ensureServerAndNotebook (c:\Users\rravi\.vscode\extensions\ms-python.python-2020.4.74986\out\client\extension.js:1:863616)
# at async C.clearResult (c:\Users\rravi\.vscode\extensions\ms-python.python-2020.4.74986\out\client\extension.js:1:859683)
# at async C.reexecuteCell (c:\Users\rravi\.vscode\extensions\ms-python.python-2020.4.74986\out\client\extension.js:1:847953)
# ...

# %%
from bs4 import BeautifulSoup as bs

# %%
import requests

# %%
url = "https://www.livechennai.com/gold_silverrate.asp"

# %%
page=requests.get(url)

# %%
data=bs(page.text,'html.parser')

# %%
#get table-price table from the website
#data=[]
table=data.find('table',attrs={'class':'table-price'})

# %%
table
# Out:
# <table class="table-price" style="border: none;">
# <tr>
# <td>
# <div class="col-sm-2">
# <table border="0" class="left-list" style="float: left;margin-top:-36px;border: none;margin-bottom: 25px;">
# <tr>
# <td valign="center" width="244"><b><font color="#ea8c00"> </font></b> <br/>
# <br/>
# <div class="left-list" id="left-gold">
# <table border="0" cellpadding="0" class="left-other-city">
# <tr align="center"><td> <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <!-- 180x90, created 5/3/11 -->
# <ins class="adsbygoogle" data-ad-client="ca-pub-5210135464026679" data-ad-format="link" data-ad-slot="2577772987" data-full-width-responsive="true" style="display:block"></ins>
# <script>
#      (adsbygoogle = window.adsbygoogle || []).push({});
# </script>
# </td></tr>
# <tr><td><a href="gold_silverrate.asp"> <span>Gold Rate in Chennai</span></a></td> </tr>
# ...

# %%
rows = table.find_all('tr')
for row in rows:
    tdl=row.find_all('td')

# %%
rows

# %%
tdl

# %%
len(tdl)

# %%
list(rows)
# Out:
# [<tr>
#  <td>
#  <div class="col-sm-2">
#  <table border="0" class="left-list" style="float: left;margin-top:-36px;border: none;margin-bottom: 25px;">
#  <tr>
#  <td valign="center" width="244"><b><font color="#ea8c00"> </font></b> <br/>
#  <br/>
#  <div class="left-list" id="left-gold">
#  <table border="0" cellpadding="0" class="left-other-city">
#  <tr align="center"><td> <script async="" src="https://pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#  <!-- 180x90, created 5/3/11 -->
#  <ins class="adsbygoogle" data-ad-client="ca-pub-5210135464026679" data-ad-format="link" data-ad-slot="2577772987" data-full-width-responsive="true" style="display:block"></ins>
#  <script>
#       (adsbygoogle = window.adsbygoogle || []).push({});
#  </script>
#  </td></tr>
#  <tr><td><a href="gold_silverrate.asp"> <span>Gold Rate in Chennai</span></a></td> </tr>
#  <tr><td> <a href="gold_silverrate_Coimbatore.asp"> <span>Gold Rate in Coimbatore</span></a></td></tr>
# ...

# %%
with open("rough_note1.txt",'w') as f:
    f.writelines(str(rows))
#     for r in list(rows):
#         print(r)

# %%
type(rows)
# Out:
# bs4.element.ResultSet

# %%
dat=data.find('font',attrs={'class':'txt-clr'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-e12589acc1c6> in <module>
# ----> 1 dat=data.find('font',attrs={'class':'txt-clr'})
#
# AttributeError: 'list' object has no attribute 'find'

# %%
dat

# %%
dat=data.find('font',attrs={'class':'txt-clr'})
dat

# %%
print(type(table))
print(type(data))

# %%
data

# %%
fnt=data.find_all('font')

# %%
fnt=iter(fnt)

# %%
fnt

# %%
this=next(fnt)

# %%
this
# Out:
# <font class="txt-clr">3817.00</font>

# %%
dir(this)
# Out:
# ['HTML_FORMATTERS',
#  'XML_FORMATTERS',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_find_all',
#  '_find_one',
#  '_formatter_for_name',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_should_pretty_print',
#  'append',
#  'attrs',
#  'can_be_empty_element',
#  'childGenerator',
#  'children',
#  'clear',
#  'contents',
#  'decode',
#  'decode_contents',
#  'decompose',
#  'descendants',
# ...

# %%
this.text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-68f2f60cf112> in <module>
# ----> 1 this.text
#
# NameError: name 'this' is not defined
